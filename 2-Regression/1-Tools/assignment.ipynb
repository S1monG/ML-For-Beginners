# %% [markdown]
# ## Assignment Linnerud

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection

# %%
X, y = datasets.load_linnerud(return_X_y=True)
print(X.shape, y.shape)
print(X[0], y[0])
# Out:
# (20, 3) (20, 3)
# [  5. 162.  60.] [191.  36.  50.]

# %%
X = X[:, 0] # All rows, first column (chins)
y = y[:, 0] # All rows, first column (weight)
X = X.reshape(-1, 1)
y = y.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (20, 1) (20, 1)

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.1) # 90% training, 10% testing
print(X_train.shape, y_train.shape)
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
# Out:
# (18, 1) (18, 1)

# %%
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.xlabel('chins')
plt.ylabel('weight')
plt.title('A Graph Plot Showing Chins Against Weight')
plt.show()

# %% [markdown]
# # Some notable connections between the features and the targets but not as much as the training set on diabetes.
# # Very small sample count so the output differs alot every time you run it.
